# %% [markdown]
# #### Have put together initial word2vec models on politics and business clusters since 1981, with all adjectives and adverbs marked.  Still searching for interesting topics for comparison over the years.

# %%
import pandas as pd
import numpy as np
import calendar
import datetime
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import NMF
from nltk.tag import pos_tag
from nltk.tokenize import word_tokenize, sent_tokenize
from time import time
import spacy
from gensim.models import Word2Vec
import gensim, multiprocessing
import pickle


def preprocess_df(df_raw):
    '''preprocesses text, returning only relevant components for remaining analysis'''
    df_raw['body'] = df_raw['text_body'].apply(join_strs)
    df_raw['len_body'] = df_raw.apply(lambda row: len(row['body']), axis = 1)
    print(df_raw.shape[0]-df_raw[df_raw['len_body']>0].shape[0],'lost records of', df_raw.shape[0])
    df_raw=df_raw[df_raw['len_body']>0]
    df_raw = df_raw.reset_index()
    df_raw['pub_year'] = df_raw.apply(lambda row: row['date'].year, axis=1)
    df_raw = df_raw.drop(['index','date','text_body','title','len_body'], axis=1)
    return df_raw


def nmf_cluster(df, vectorizer_feats = 1000, n_topics = 5):
    '''clusters articles in to different groupings, uses TFIDF vectorizer by default
    returns labeled dataframe'''
    df = df.rename(columns={'index':'original_index'})
    df = df.reset_index()
    df= df.drop(['index'], axis = 1)
    tfidf_vectorizer = TfidfVectorizer(max_df=0.80, min_df=2,
                               max_features=vectorizer_feats,
                               stop_words='english')
    tfidf = tfidf_vectorizer.fit_transform(df['body'])
    nmf = NMF(n_components=n_topics, random_state=1,
          alpha=.1, l1_ratio=.5).fit(tfidf)
    topic_score = pd.DataFrame(nmf.fit_transform(tfidf))
    topic_score['categ'] = topic_score[[n for n in range(n_topics)]].idxmax(axis=1)
    topic_score['categ_score'] = topic_score[[n for n in range(n_topics)]].max(axis=1)
    topic_score['categ_2score'] = pd.DataFrame(np.sort(topic_score[[n for n in range(n_topics)]].values)[:,-2:], \
                                           columns=['2nd-largest','largest'])['2nd-largest']
    topic_score['topic_diff'] = topic_score.apply(lambda row: row['categ_score'] - row['categ_2score'], axis = 1)
    df['categ_index'] = topic_score['categ']
    topic_keys = get_clusters(model = nmf, feature_names = tfidf_vectorizer.get_feature_names(), keywords = keywords, n_topics = n_topics)
    df["categ"] = df.apply(lambda row: topic_keys[row.categ_index] , axis=1)
    df = df.drop(['categ_index'], axis =1)
    df = df[df["categ"]!='NAP']
    return(df, nmf, tfidf)


keywords = {"politics": [ 'administration', 'al', 'american', 'budget', 'bush', 'campaign', 'chairman', 'clinton',\
                         'committee', 'congress', 'country', 'county', 'court', 'democrat', 'democratic',\
                         'democrats', 'department', 'election', 'federal', 'forces', 'gore', 'government',\
                         'governor', 'house', 'intelligence', 'iran', 'iraq', 'islamic', 'judge', 'law',\
                         'mccain', 'military', 'mondale', 'obama', 'officers', 'official', 'officials',\
                         'party', 'police', 'political', 'president', 'reagan', 'republican', 'republicans',\
                         'russia', 'russian', 'security', 'senate', 'senator', 'spending', 'state', 'states',\
                         'syria', 'tax', 'today', 'united', 'vote', 'war', 'white'],
            "business": ["company","companies","market","billion","million","banks","financial", "finance",\
                         "economy", "industry"]}


def get_clusters(model, feature_names, keywords, threshold = 5, n_top_words = 30, n_topics = 5):
    '''Assigns topic types based on keywords provided'''
    topic_key = {m:'NAP' for m in range(n_topics)}
    for topic_idx, topic in enumerate(model.components_):
        topic_words = [feature_names[i] for i in topic.argsort()[:-n_top_words - 1:-1]]
        for key in keywords.keys():
            overlap = len(set(keywords[key]) & set(topic_words))
            if overlap>threshold:
                topic_key[topic_idx] = key
    return topic_key    
    
tags = ["JJ","JJR","JJS","RB","RBR","RBS"]

def marker(sentences, to_tag):
    ''' Adds "markedword" to all adjectives/adverbs, for easy reference later '''
    words_final = []
    for sentence in sent_tokenize(sentences):
        for word in pos_tag(word_tokenize(sentence)):
            if word[1] in to_tag:
                words_final.append(word[0]+word[1]+"markedword")
            else:
                words_final.append(word[0])
    return ' '.join(words_final)

def preprocess_text(df, tags = tags):
    '''Tag all words with adjectives/adverbs to find descriptors '''
    t0 = time()
    df['marked_text'] = df['body'].apply(marker, args=(tags,))
    df = df.drop(['url','body','pub_year'],axis=1)
    return df

def print_top_words(model, feature_names, n_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print("Topic #%d:" % topic_idx)
        print(" ".join([feature_names[i]
                        for i in topic.argsort()[:-n_top_words - 1:-1]]))
        print("")
    
def word2vec_models(df):
    '''Takes all text from datafram and returns word2vec model for each topic'''
    final_models = {}
    categs = df.categ.unique()
    for categ in categs:
        input_string = u''
        temp_df = df[df['categ']==categ]
        for m in range(temp_df.shape[0]):
            input_string += temp_df.loc[temp_df.index[m]].marked_text
        nlp = spacy.load('en')
        processed_text = nlp(input_string)
        sentences = [s for s in processed_text.sents]
        processed_sentences = [sent.lemma_.split() for sent in processed_text.sents]
        attributes_model = Word2Vec(
                sentences=processed_sentences,
                workers=multiprocessing.cpu_count() - 1, # use all cores
                window=50, sg=1)
        final_models[categ] = attributes_model
        print("done with %s categ in %0.3fs." % (categ, time() - t0))
        del input_string, temp_df, sentences, processed_text, nlp, processed_sentences
    return final_models
# Out:
# Using Theano backend.

# %% [markdown]
# ## Read in all data, and merge articles into one dataframe

# %%
df0 = pd.read_json('data/full_articles/1981_1995_articles.json')
df1 = pd.read_json('data/full_articles/1996_1999_articles.json')
df2 = pd.read_json('data/full_articles/2000_2009_articles.json')
df3 = pd.read_json('data/full_articles/2010_2015_articles.json')
df4 = pd.read_json('data/full_articles/2007_2016_2017_articles.json')

# %%
months = dict((v,k) for k,v in enumerate(calendar.month_abbr))

def date_convert(text):
    text = text.split(('Published: '))[1]
    month = months[text[0:3]]
    day = int(text.split(',')[0].split(' ')[1])
    year = int(text[-4:])
    return pd.Timestamp(datetime.datetime(year, month,day))

df0['date'] = df0['date'].apply(date_convert)

# %%
df = df0.append(df1, ignore_index=True).append(df2, ignore_index=True).append(df3, ignore_index=True).append(df4, ignore_index=True)

# %%
t0 = time()
df_final = preprocess_df(df)
print("done in %0.3fs." % (time() - t0))
# Out:
# (11782, 'lost records of', 331362)
# done in 68.470s.

# %%
del df
df_final = df_final.dropna()
with open('data/pickles/model/df_final.pkl', 'wb') as f:
        pickle.dump(df_final, f)

# %%
with open('data/pickles/model/df_final.pkl', 'rb') as f:
        df_final = pickle.load(f)

# %%
df_final.head()
# Out:
#                                                  url  \
# 0  https://www.nytimes.com/1981/01/03/us/snowfall...
# 1  https://www.nytimes.com/1981/01/03/nyregion/ma...
# 2  https://www.nytimes.com/1981/01/03/business/pr...
# 3  https://www.nytimes.com/1981/01/03/world/hundr...
# 4  https://www.nytimes.com/1981/01/03/us/gop-is-a...
#
#                                                 body  pub_year
# 0  \n \nThe ski industry in the eastern half of t...    1981.0
# 1  \nMore than two-thirds of the nightclubs, disc...    1981.0
# 2  \nBanks across the country, reversing a patter...    1981.0
# 3  \n \nDespite a recent effort to create a fair ...    1981.0
# 4  \n \nUsing campaign contributions, computer pr...    1981.0

# %%
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %% [markdown]
# ## Cycle through each time period, number of topics; return an nmf, dataframe, and TFIDF Vectorizer

# %%
intervals = [(m, m+3) for m in range(1981, 2017, 4)]

# %%
t0 = time()

nmf_models = {}
for interval in intervals:
    curr_df = df_final[(df_final['pub_year']>=interval[0]) & (df_final['pub_year']<=interval[1])]
    df, nmf, tfidf = nmf_cluster(curr_df, n_topics = 5)
    nmf_models[interval] = (df, nmf, tfidf)
    print(topic_keys)
    print(interval, "done in %0.3fs." % (time() - t0))
# Out:
# categ
# ((1981, 1984), 'done in 41.525s.')
# categ
# ((1985, 1988), 'done in 84.723s.')
# categ
# ((1989, 1992), 'done in 127.450s.')
# categ
# ((1993, 1996), 'done in 173.848s.')
# categ
# ((1997, 2000), 'done in 249.855s.')
# categ
# ((2001, 2004), 'done in 337.796s.')
# categ
# ((2005, 2008), 'done in 408.877s.')
# categ
# ((2009, 2012), 'done in 459.560s.')
# categ
# ((2013, 2016), 'done in 502.151s.')

# %%
with open('data/pickles/model/nmf/nmf_5topics.pkl', 'wb') as f:
        pickle.dump(nmf_models, f)

# %% [markdown]
# ## Topic Summaries

# %%
with open('data/pickles/model/nmf/nmf_5topics.pkl', 'rb') as f:
        nmf_models = pickle.load(f)

# %%
for year in range(1981, 2014, 4):
    print((year, year+3))
    print_top_words(nmf_models[(year,year+3)][1], nmf_models[(year,year+3)][2].get_feature_names(), 30)
    print ('--------------------------------')
# Out:
# (1981, 1984)
# Topic #0:
# tax reagan budget house senate a1 president administration state billion congress republican spending federal democrats committee senator cuts taxes new fiscal white year deficit program democratic republicans percent programs economic
#
# Topic #1:
# percent company million market oil prices stock companies rates sales billion year quarter d1 bank rate rose price industry banks analysts shares new business corporation earnings share trading fell economy
#
# Topic #2:
# new city york people dr street game school years like year time 000 old season day just miss home building work children center state avenue park play mrs team police
#
# Topic #3:
# soviet united states israel american military israeli lebanon reagan union officials government administration beirut minister forces lebanese president missiles foreign a1 arms nuclear talks official nations west moscow troops today
#
# Topic #4:
# mr mondale company county party court state campaign judge president case investigation chairman office governor attorney democratic mayor district justice executive police political charges years republican election board asked did
#
# --------------------------------
# (1985, 1988)
# Topic #0:
# city new mr people york 000 dr state street years school building year police like old children county work housing mrs manhattan island mayor avenue park square center family time
#
# Topic #1:
# company percent stock million market billion prices d1 companies oil dollar year bank analysts trading share shares sales industry new rates price business economy quarter tax rose rate markets corporation
#
# Topic #2:
# mr soviet reagan president united states officials administration american house government military today white official gorbachev party political arms state senate union meeting republican senator iran congress shultz bush committee
#
# Topic #3:
# page paper stand information provided yesterday appeared nyt d1 new police a1 york south times france president court left died killed washington minister africa day government paul john officials american
#
# Topic #4:
# game season games team play mets ball second league hit players run left field won got victory time just right runs lead like home didn played don series points win
#
# --------------------------------
# (1989, 1992)
# Topic #0:
# city state new york mayor dinkins police mr budget county tax housing 000 officials board jersey plan school court department million cuomo year council governor officers law federal manhattan public
#
# Topic #1:
# company percent d1 market million companies stock billion prices sales year industry bank business new economy oil banks rates american quarter price analysts japanese trading markets rose japan securities corporation
#
# Topic #2:
# page paper stand provided appeared information photo times york yesterday new d1 press france soviet president left news killed day bush minister john died park south israel aids brooklyn jr
#
# Topic #3:
# mr bush soviet president party gorbachev united political government house today campaign clinton military states administration american officials union congress republican iraq white democratic war committee minister democrats senator leaders
#
# Topic #4:
# dr like game people old years children just year new time ms season home women school play team life don mrs day work family world way man university street good
#
# --------------------------------
# (1993, 1996)
# Topic #0:
# dr like people ms game just time years new old year children life home don team day women season way play world good work know says family street going young
#
# Topic #1:
# company percent companies market stock million billion d1 year prices sales business new industry investors rates price economy shares american analysts stocks computer trade bank markets 000 quarter japan share
#
# Topic #2:
# page paper stand provided appeared information photo times york new yesterday associated press d1 clinton president park b3 left united reports bosnia nations killed bosnian day street brooklyn israel peace
#
# Topic #3:
# mr clinton president house dole republican party united white campaign political republicans government today senator senate administration states officials congress democrats democratic american military committee election vote did nations federal
#
# Topic #4:
# city new state police york mayor school jersey giuliani b3 schools officials county court yesterday board department budget officers education year federal law students million governor district brooklyn public council
#
# --------------------------------
# (1997, 2000)
# Topic #0:
# new ms city people like dr york school years children year street 000 work music old life time just women state art students mr family theater police building center day
#
# Topic #1:
# game yankees team season knicks mets games players play coach league ball second left points series run player hit night field teams right just win victory jets fans lead won
#
# Topic #2:
# company percent stock companies market billion investors million year stocks shares internet sales prices business analysts earnings industry price bank quarter financial new microsoft deal technology economy growth rose markets
#
# Topic #3:
# mr clinton president campaign party republican house bush political gore state republicans democratic today democrats government senate officials white election senator court vote case committee police united governor law lawyers
#
# Topic #4:
# page clinton president new officials united house court states china federal american administration senate state government york military nato war nations plan drug city congress arts russia republican republicans jersey
#
# --------------------------------
# (2001, 2004)
# Topic #0:
# ms new city like people york dr school years children just street old time year 000 work music life center home family women day art building don way world say
#
# Topic #1:
# percent company billion million companies year stock sales market quarter bank investors shares business analysts profit economy chief industry financial prices executive growth executives rose price government largest earnings share
#
# Topic #2:
# game yankees season team games play players coach mets league ball field points second giants series run player hit left knicks teams night fans victory win nets right won baseball
#
# Topic #3:
# iraq bush american page united officials military war states iraqi administration government hussein security forces president al nations intelligence weapons troops attacks afghanistan taliban qaeda official today soldiers pentagon attack
#
# Topic #4:
# mr campaign governor bush party state republican president board political democratic house company case democrats court executive did senator election mayor kerry chief chairman office new lawyer senate lawyers republicans
#
# --------------------------------
# (2005, 2008)
# Topic #0:
# mr campaign case company obama film man lawyer news trial time did political executive music prosecutors office governor party board chief president attorney years republican york movie lawyers business book
#
# Topic #1:
# game yankees season team mets games players play coach ball league field second run points giants left player hit victory night teams right fans baseball football lead win just runs
#
# Topic #2:
# company percent companies billion market million year prices investors sales stock financial industry business bank chief price executive oil executives 000 investment banks money economy analysts credit markets firm mortgage
#
# Topic #3:
# ms city people dr school children old life women just years york family year time home work house music mother street 000 art day parents book don young building way
#
# Topic #4:
# iraq bush officials american government military iraqi state security administration united states war political president republican baghdad democrats police al troops forces senate army senator republicans leaders democratic official intelligence
#
# --------------------------------
# (2009, 2012)
# Topic #0:
# ms people dr women city life children art book just school family mother work time old york years young home woman don music way year love parents theater museum world
#
# Topic #1:
# percent company bank banks companies billion market year financial million government investors sales industry money debt economy 000 prices european business china states markets stock united federal chief pay credit
#
# Topic #2:
# mr music film company movie man work york theater time book news production years audience night million business romney director television story band just life performance did executive says people
#
# Topic #3:
# game season team games players play coach league ball field football player teams sunday second fans win just run played time hit saturday did series left points won final playing
#
# Topic #4:
# obama mr officials government republican military republicans president state administration american house democrats states political united senate campaign security afghanistan party romney washington election health congress law white democratic tax
#
# --------------------------------
# (2013, 2016)
# Topic #0:
# ms music art life people film women just work city book time york family movie theater years story old young black mother way museum man love don children night home
#
# Topic #1:
# obama state officials government military american united states police islamic syria president security russia administration iraq russian law court war al intelligence forces political house department iran official country officers
#
# Topic #2:
# trump clinton mrs republican campaign voters republicans party election democrats presidential democratic obama president senator candidate political candidates bush vote senate race conservative house primary supporters white state support governor
#
# Topic #3:
# company percent companies china million market year billion business industry bank investors sales executive chinese chief financial 000 economy technology money data growth workers prices years people price products states
#
# Topic #4:
# game season players team games league coach play football player fans field sports points second sunday played series win time final just playing did year won left minutes best night
#
# --------------------------------

# %% [markdown]
# ## Create Word2Vec Models Based on Dataframes

# %%
models1={}
for interval in intervals[0:3]:
    t0 = time()
    df_og = nmf_models[interval][0]
    df_curr = preprocess_text(df_og)
    models = word2vec_models(df_curr)
    models1[interval] = models
    print(interval, "done in %0.3fs." % (time() - t0))
    
models2={}
for interval in intervals[3:6]:
    t0 = time()
    df_og = nmf_models[interval][0]
    df_curr = preprocess_text(df_og)
    models = word2vec_models(df_curr)
    models2[interval] = models
    print(interval, "done in %0.3fs." % (time() - t0))

models3={}
for interval in intervals[6:9]:
    t0 = time()
    df_og = nmf_models[interval][0]
    df_curr = preprocess_text(df_og)
    models = word2vec_models(df_curr)
    models3[interval] = models
    print(interval, "done in %0.3fs." % (time() - t0))

models = {}
for key in models1.keys():
    models[key] = models1[key]

for key in models2.keys():
    models[key] = models2[key]

for key in models3.keys():
    models[key] = models3[key]
# Out:
# done with business categ in 847.986s.
# done with politics categ in 1489.791s.
# ((1981, 1984), 'done in 1490.050s.')
# done with business categ in 1027.041s.
# done with politics categ in 1591.042s.
# ((1985, 1988), 'done in 1591.246s.')
# done with business categ in 982.018s.
# done with politics categ in 1475.091s.
# ((1989, 1992), 'done in 1475.315s.')
# done with politics categ in 1132.047s.
# done with business categ in 1551.971s.
# ((1993, 1996), 'done in 1552.182s.')
# done with politics categ in 1720.795s.
# done with business categ in 2431.942s.
# ((1997, 2000), 'done in 2432.213s.')
# done with business categ in 1659.723s.
# done with politics categ in 2795.704s.
# ((2001, 2004), 'done in 2796.120s.')
# done with business categ in 1617.136s.
# done with politics categ in 2358.714s.
# ((2005, 2008), 'done in 2359.030s.')
# done with business categ in 1353.609s.
# done with politics categ in 1726.139s.
# ((2009, 2012), 'done in 1726.342s.')
# done with business categ in 1063.195s.
# done with politics categ in 1534.869s.
# ((2013, 2016), 'done in 1535.105s.')

# %%
with open('../data/pickles/model/word2vec_8.15.pkl', 'rb') as f:
        word2vec = pickle.load(f)

# %%
sorted(word2vec[(1981,1984)].keys())

def descibers_over_time_all(dict_models, categ, word):
    for key in sorted(dict_models.keys()):
        print(key)
        for w,sim in dict_models[key][categ].most_similar(word,topn=10):
            if (w[-10:]=="markedword"):
                print((w[:-12], sim))
            else:
                print((w, sim))
        print("------------")
        
def descibers_over_time(dict_models, categ, word):
    for key in sorted(dict_models.keys()):
        print(key)
        for w,sim in dict_models[key][categ].most_similar(word,topn=150):
            if (w[-10:]=="markedword"):
                print((w[:-12], sim))
        print("------------")

# %%
descibers_over_time(word2vec, 'politics', 'iran')
# Out:
# (1981, 1984)
# (u'iranian', 0.9057307243347168)
# (u'persian', 0.7032240629196167)
# (u'unimaginable', 0.6348543167114258)
# (u'islamic', 0.6282001733779907)
# (u'shadowy', 0.614230751991272)
# (u'algerian', 0.6050736308097839)
# (u'arab', 0.574299693107605)
# (u'gulf', 0.5737534165382385)
# (u'frozen', 0.57230544090271)
# (u'debatable', 0.5679643154144287)
# (u'implacable', 0.5642850399017334)
# (u'50-mile', 0.5468552112579346)
# (u'insane', 0.5467159152030945)
# (u'feeble', 0.5325487852096558)
# (u'14-month', 0.530278205871582)
# (u'israel', 0.5294326543807983)
# (u'producing', 0.5207966566085815)
# (u'fertile', 0.519006609916687)
# (u'unambiguous', 0.5158731341362)
# (u'qaddafi', 0.5152394771575928)
# (u'undefined', 0.5118025541305542)
# (u'imaginative', 0.5096311569213867)
# ------------
# (1985, 1988)
# (u'iranian', 0.7790703773498535)
# (u'persian', 0.6299331188201904)
# (u'hostages', 0.5693492293357849)
# (u'iran', 0.5681303143501282)
# (u'denial', 0.5594326257705688)
# (u'gulf', 0.5429402589797974)
# (u'diplomatically', 0.5420953035354614)
# (u'secret', 0.5420112013816833)
# (u'hostage', 0.5371867418289185)
# (u'sale', 0.5364751815795898)
# (u'unintentional', 0.5360105037689209)
# (u'mine', 0.5261617302894592)
# (u'nicaraguan', 0.5245755314826965)
# (u'tangled', 0.5240392684936523)
# (u'strategically', 0.5226550698280334)
# (u'renewed', 0.5209805369377136)
# (u'unsigned', 0.5095243453979492)
# (u'tacitly', 0.5091305375099182)
# (u'covert', 0.5010368824005127)
# (u'shadowy', 0.49920570850372314)
# (u'contra', 0.4978139400482178)
# (u'destroy', 0.4969691038131714)
# (u'criticized', 0.49556541442871094)
# (u'sorely', 0.49059605598449707)
# (u'untrue', 0.48911434412002563)
# (u'barbaric', 0.4861840009689331)
# (u'belatedly', 0.48382773995399475)
# (u'fire', 0.4810783565044403)
# ------------
# (1989, 1992)
# (u'contra', 0.7378840446472168)
# (u'hostages', 0.7189332246780396)
# (u'iranian', 0.6685465574264526)
# (u'sale', 0.6630871891975403)
# (u'nicaraguan', 0.6585976481437683)
# (u'diary', 0.6293727159500122)
# (u'fragmentary', 0.6211256384849548)
# (u'peripheral', 0.5902340412139893)
# (u'exhaustive', 0.5901143550872803)
# (u'secret', 0.5771937370300293)
# (u'covert', 0.5746780037879944)
# (u'clandestine', 0.5696734189987183)
# (u'sandinista', 0.5591336488723755)
# (u'convenient', 0.546200156211853)
# (u'superior', 0.5452498197555542)
# (u'rear', 0.5441262125968933)
# (u'finding', 0.539114236831665)
# (u'classified', 0.5318611860275269)
# (u'immunized', 0.5289199948310852)
# (u'enigmatic', 0.5288587808609009)
# (u'admiral', 0.5224863886833191)
# (u'unfolding', 0.5203666687011719)
# (u'tribunal', 0.5193326473236084)
# (u'flawed', 0.5122460722923279)
# (u'turning', 0.5097482204437256)
# (u'recorded', 0.5092054605484009)
# (u'sworn', 0.5080849528312683)
# (u'mistrial', 0.5063552260398865)
# (u'sketchy', 0.5060734748840332)
# (u'destroyed', 0.5060683488845825)
# (u'impeachment', 0.5040197372436523)
# (u'plagued', 0.5036748647689819)
# (u'captured', 0.5025357007980347)
# (u'crimes', 0.5008631348609924)
# (u'unexplained', 0.4963250160217285)
# (u'falsely', 0.49604952335357666)
# (u'intricate', 0.4951203465461731)
# ------------
# (1993, 1996)
# (u'iranian', 0.6402733325958252)
# (u'iraqi', 0.6014578938484192)
# (u'contra', 0.5953941345214844)
# (u'ballistic', 0.5457527041435242)
# (u'gulf', 0.5363414287567139)
# (u'appeasement', 0.5357476472854614)
# (u'persian', 0.5263984799385071)
# (u'kurdish', 0.5187357664108276)
# (u'tat', 0.5186623334884644)
# (u'smuggled', 0.5176699161529541)
# (u'phased', 0.5133856534957886)
# (u'grudging', 0.5128865838050842)
# (u'abortive', 0.5118820667266846)
# (u'squad', 0.5118358135223389)
# (u'era', 0.5116850137710571)
# (u'captured', 0.51003098487854)
# (u'oppose', 0.5063787698745728)
# (u'intelligence', 0.5056644082069397)
# (u'nuclear', 0.5054296851158142)
# (u'arabian', 0.505210280418396)
# (u'islamic', 0.500874936580658)
# (u'adhere', 0.5006167888641357)
# (u'resistant', 0.500458836555481)
# (u'unconnected', 0.5000917911529541)
# (u'importantly', 0.499981552362442)
# (u'rogue', 0.4995044469833374)
# (u'chemical', 0.49624866247177124)
# (u'crimes', 0.4960933029651642)
# ------------
# (1997, 2000)
# (u'iranian', 0.7536494731903076)
# (u'rogue', 0.6214699745178223)
# (u'poisonous', 0.5912991762161255)
# (u'puritanical', 0.5911425948143005)
# (u'democratically', 0.5747913122177124)
# (u'soviet', 0.5674985647201538)
# (u'islamic', 0.558566153049469)
# (u'ballistic', 0.5580704212188721)
# (u'fundamentalist', 0.5566381216049194)
# (u'uncompromising', 0.5455679893493652)
# (u'obliquely', 0.5422202348709106)
# (u'missile', 0.5400035977363586)
# (u'titular', 0.5337609052658081)
# (u'chilean', 0.5324351787567139)
# (u'warhead', 0.5296961665153503)
# (u'range', 0.5280629396438599)
# (u'nuclear', 0.5259137153625488)
# (u'inadequately', 0.5253361463546753)
# (u'undetected', 0.5225296020507812)
# (u'foreign', 0.5221713185310364)
# (u'american', 0.5168582201004028)
# (u'abroad', 0.5166671276092529)
# (u'reformist', 0.5164561867713928)
# (u'antimissile', 0.5160245895385742)
# (u'arsenal', 0.5152081251144409)
# (u'arab', 0.5126588344573975)
# (u'peace', 0.5122450590133667)
# (u'punish', 0.5113357305526733)
# (u'launched', 0.5111526846885681)
# (u'dictatorial', 0.5098522305488586)
# (u'contra', 0.509382426738739)
# (u'bilateral', 0.5066290497779846)
# (u'tat', 0.5046646595001221)
# (u'submarine', 0.5038275718688965)
# (u'permissive', 0.5033326148986816)
# (u'developing', 0.5023597478866577)
# (u'virulently', 0.501758337020874)
# (u'militarily', 0.5001610517501831)
# ------------
# (2001, 2004)
# (u'iranian', 0.8480361104011536)
# (u'installed', 0.6774492859840393)
# (u'intensifying', 0.6345178484916687)
# (u'nuclear', 0.6308179497718811)
# (u'kurdish', 0.6298685669898987)
# (u'sanctuary', 0.6265460848808289)
# (u'clandestinely', 0.6205296516418457)
# (u'establishing', 0.6184160113334656)
# (u'pakistani', 0.6169894933700562)
# (u'engagement', 0.6158239841461182)
# (u'reformist', 0.6109000444412231)
# (u'russia', 0.6022325754165649)
# (u'supplied', 0.5994381904602051)
# (u'oppressed', 0.598508358001709)
# (u'transnational', 0.5983127355575562)
# (u'unfriendly', 0.5964688062667847)
# (u'emerging', 0.5949603319168091)
# (u'destabilizing', 0.5941153764724731)
# (u'andean', 0.5891821384429932)
# (u'pakistan', 0.5882508158683777)
# (u'indirect', 0.5863409638404846)
# (u'backed', 0.5851377248764038)
# (u'frontierj', 0.5798515677452087)
# (u'northern', 0.5768344402313232)
# (u'incipient', 0.5765102505683899)
# (u'predominately', 0.5761986970901489)
# (u'enrichment', 0.5752487778663635)
# (u'urging', 0.5743523836135864)
# (u'western', 0.5739414095878601)
# (u'gravestj', 0.5734251737594604)
# (u'islamist', 0.5731884241104126)
# (u'baathist', 0.5682209134101868)
# (u'possess', 0.5681776404380798)
# (u'exile', 0.5652205944061279)
# (u'fatwa', 0.564595103263855)
# (u'revolutionary', 0.5644087195396423)
# (u'islamic', 0.5638844966888428)
# (u'nicaraguan', 0.5635675191879272)
# (u'fundamentalist', 0.5631341338157654)
# (u'militant', 0.5627516508102417)
# ------------
# (2005, 2008)
# (u'iranian', 0.8096665143966675)
# (u'enrichment', 0.8058744072914124)
# (u'nuclear', 0.777520477771759)
# (u'diplomatic', 0.7059292793273926)
# (u'regime', 0.6912767887115479)
# (u'uranium', 0.6817890405654907)
# (u'repressive', 0.6715982556343079)
# (u'unconditional', 0.6706714034080505)
# (u'rogue', 0.6552742123603821)
# (u'multilateral', 0.6472969055175781)
# (u'bilateral', 0.6460204124450684)
# (u'militarily', 0.6445062160491943)
# (u'foreign', 0.6422673463821411)
# (u'inextricably', 0.6413798332214355)
# (u'sovereign', 0.6362559795379639)
# (u'nicaraguan', 0.6244981288909912)
# (u'arab', 0.6231045722961426)
# (u'aloof', 0.6125572919845581)
# (u'defeating', 0.6124919652938843)
# (u'allied', 0.6089203953742981)
# (u'persian', 0.6052889823913574)
# (u'forth', 0.603717565536499)
# (u'diplomatically', 0.6013128161430359)
# (u'pre-9/11', 0.5990607738494873)
# (u'biological', 0.5958239436149597)
# (u'semiautonomous', 0.5926954746246338)
# (u'expansively', 0.5880094170570374)
# (u'separatist', 0.5863091349601746)
# (u'functioning', 0.5830613970756531)
# (u'stated', 0.5796453952789307)
# (u'finding', 0.5761438608169556)
# (u'resurgent', 0.5728634595870972)
# (u'freerj', 0.5723480582237244)
# (u'counterproductive', 0.5710613131523132)
# (u'european', 0.5699496269226074)
# ------------
# (2009, 2012)
# (u'nuclear', 0.8334321975708008)
# (u'iranian', 0.8025543689727783)
# (u'bilateral', 0.7106525897979736)
# (u'ballistic', 0.6981903314590454)
# (u'emptive', 0.6865367889404297)
# (u'antimissile', 0.6841357350349426)
# (u'israeli', 0.6828553676605225)
# (u'diplomatic', 0.679646372795105)
# (u'uranium', 0.6753035187721252)
# (u'sovereign', 0.674025297164917)
# (u'intercontinental', 0.6712143421173096)
# (u'virulently', 0.6699330806732178)
# (u'amenable', 0.6576966047286987)
# (u'loath', 0.6517326235771179)
# (u'narrowerj', 0.6415262818336487)
# (u'arab', 0.6269122362136841)
# (u'prompt', 0.6245822906494141)
# (u'undemocratic', 0.6230624914169312)
# (u'measured', 0.6204044818878174)
# (u'diplomatically', 0.6197842359542847)
# (u'persian', 0.6175215244293213)
# (u'tougher', 0.6160257458686829)
# (u'quid', 0.6149536967277527)
# (u'territorial', 0.6143486499786377)
# (u'assad', 0.6123045682907104)
# (u'unilateral', 0.6100782752037048)
# (u'channel', 0.6083486080169678)
# (u'repressive', 0.6067878603935242)
# (u'staunchly', 0.6034717559814453)
# (u'vociferous', 0.6020923256874084)
# (u'unrestj', 0.5997430086135864)
# (u'oblivious', 0.599112331867218)
# (u'tacitly', 0.5988752841949463)
# (u'multilateral', 0.5971236228942871)
# (u'reviled', 0.5962502956390381)
# (u'staunchestj', 0.5956311225891113)
# (u'islamic', 0.5931720733642578)
# (u'israel', 0.590449869632721)
# (u'supreme', 0.5904492139816284)
# (u'radicalized', 0.5903406143188477)
# (u'tactical', 0.5900635123252869)
# (u'preferable', 0.589963972568512)
# ------------
# (2013, 2016)
# (u'iranian', 0.815965473651886)
# (u'nuclear', 0.7903237342834473)
# (u'uranium', 0.6886228322982788)
# (u'bent', 0.6731821298599243)
# (u'iran\u2019s', 0.6689931154251099)
# (u'enrichment', 0.6500546336174011)
# (u'tangled', 0.649287223815918)
# (u'nonnuclear', 0.6356226801872253)
# (u'implacable', 0.626183271408081)
# (u'iran', 0.6260747313499451)
# (u'negotiating', 0.6228070259094238)
# (u'supreme', 0.6207174062728882)
# (u'belligerent', 0.6193045377731323)
# (u'saving', 0.6128306984901428)
# (u'handsomely', 0.6114227771759033)
# (u'cooperative', 0.609948992729187)
# (u'saudi', 0.6096495985984802)
# (u'outwardly', 0.6082223653793335)
# (u'covertly', 0.6053666472434998)
# (u'impotent', 0.6051636934280396)
# (u'fissile', 0.6027334332466125)
# (u'nosed', 0.6020712852478027)
# (u'kingdom\u2019s', 0.5995279550552368)
# (u'persian', 0.5976459383964539)
# (u'unfulfilled', 0.5973923206329346)
# (u'regime', 0.5956846475601196)
# (u'proxy', 0.5940908193588257)
# (u'feverish', 0.5936353802680969)
# (u'nonstate', 0.5900446772575378)
# (u'enriched', 0.5892707109451294)
# (u'reciprocal', 0.5872077941894531)
# (u'have', 0.5859224200248718)
# (u'grandiose', 0.5829225778579712)
# (u'unenthusiastic', 0.5807004570960999)
# (u'domestically', 0.5806220769882202)
# (u'amenable', 0.5777605175971985)
# (u'gulf', 0.577716052532196)
# (u'missile', 0.576850175857544)
# (u'inconceivable', 0.5768203139305115)
# (u'ballistic', 0.5754270553588867)
# ------------
